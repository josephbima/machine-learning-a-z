# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
"""
To build a polynomial regression model, we first need to build a feature with 
the power of one feature (x1 + x1^2 + ... + x1^n), and then use a linear regessor object
to train the coefficients for each features.
"""
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X) # This is the matrix of powered features

plr = LinearRegression()
plr.fit(X_poly,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(X,y, color='red')
plt.plot(X,lr.predict(X),color='blue')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(X,y, color = 'red')
plt.plot(X, plr.predict(X_poly),color = 'blue')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
# This code is just. for better resolution
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape(len(X_grid),1)
plt.scatter(X,y,color='red')
plt.plot(X_grid, plr.predict(poly_reg.fit_transform(X_grid)),color='blue')
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lr.predict([[6.5]]) # Bad prediction
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
# We need to create a feature where 6.5 would need to be a powered feature that corresponds with the degree
# We use the same method when we created X_poly, which is the powered features of X

plr.predict(poly_reg.fit_transform([[6.5]])) # Great prediction
# Out:
# array([158862.45265155])
